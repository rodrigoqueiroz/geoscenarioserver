# %%
import pandas as pd
import os

# %%
dataset_config = {}
dataset_config["base_dir"] = '/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/'
dataset_config["version"] = '1.2'
dataset_config["recording_map"] = ['DR_DEU_Merging_MT', 'DR_DEU_Roundabout_OF']

# %%
class InteractionDataset():
   

    def __init__(self, config, train=True):
        self.config = config
        self.train = train
        
        if self.train:
            self.base_dir = config["base_dir"]
            self.recording_map = config["recording_map"]
            self.csv_dir_list = [self.get_track_directory(recording) for recording in self.recording_map]
            self.osm_dir_list = [self.get_map_directory(recording) for recording in self.recording_map]
            
        else:
            self.base_dir = config["base_dir"]
            self.recording_map = config["recording_map"]
            self.csv_dir_list = [self.get_track_directory(recording) for recording in self.recording_map]
            self.osm_dir_list = [self.get_map_directory(recording) for recording in self.recording_map]
    
    def get_track_directory(self, recording):
        return self.base_dir+'train/'+recording+'_train.csv' if self.train else self.base_dir+'val/'+recording+'_val.csv'
        
    def get_map_directory(self, recording):
        return self.base_dir+'maps/'+recording+'.osm'
    
    def read_dataset(self):
        for ind, directory in enumerate(self.csv_dir_list):
            recording_df = pd.read_csv(directory)
            case_id_list = recording_df['case_id'].unique()
            # take the same case 
            # for debug use
            break
            
    def get_recording_df(self, recording):
        assert recording in self.recording_map
        return pd.read_csv(directory)
    
    def get_case_df_of_recording(self, case_id, recording_df):
        case_id_list = recording_df['case_id'].unique()
        assert case_id in case_is_list()

# %%
ID = InteractionDataset(dataset_config, train=False)
# ID.read_interaction_data()
ID.get_track_directory('DR_DEU_Merging_MT')
# Out:
# '/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/val/DR_DEU_Merging_MT_val.csv'

# %%
ID.csv_dir_list
# Out:
# ['/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/val/DR_DEU_Merging_MT_val.csv',
#  '/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/val/DR_DEU_Roundabout_OF_val.csv']

# %%
ID.osm_dir_list
# Out:
# ['/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/maps/DR_DEU_Merging_MT.osm',
#  '/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/maps/DR_DEU_Roundabout_OF.osm']

# %%
for i, v in enumerate(dataset_config["recording_map"]):
    df = pd.read_csv()
# Out:
# 0 DR_DEU_Merging_MT
# 1 DR_DEU_Roundabout_OF

# %%
pd.read_csv('/mnt/Data/Research_Dataset/INTERACTION-Dataset-DR-multi-v1_2/val/DR_DEU_Merging_MT_val.csv')
# Out:
#        case_id  track_id  frame_id  timestamp_ms agent_type        x  \
# 0          1.0         1         1           100        car  908.414
# 1          1.0         2         1           100        car  923.506
# 2          1.0         3         1           100        car  931.861
# 3          1.0         1         2           200        car  907.598
# 4          1.0         2         2           200        car  922.867
# ...        ...       ...       ...           ...        ...      ...
# 91605    343.0         3        39          3900        car  924.016
# 91606    343.0         4        39          3900        car  939.835
# 91607    343.0         2        40          4000        car  903.756
# 91608    343.0         3        40          4000        car  923.371
# 91609    343.0         4        40          4000        car  939.264
#
#               y     vx     vy  psi_rad  length  width
# 0      1006.631 -8.165  0.685    3.058    4.66   1.88
# 1      1005.483 -6.397  0.423    3.076    3.83   1.70
# 2      1004.774 -5.793  0.332    3.084    4.32   1.77
# 3      1006.699 -8.217  0.683    3.059    4.66   1.88
# 4      1005.527 -6.399  0.430    3.074    3.83   1.70
# ...         ...    ...    ...      ...     ...    ...
# 91605  1005.576 -6.450  0.324    3.091    4.15   1.82
# 91606  1004.726 -5.709  0.034    3.136    4.29   1.75
# 91607  1007.267 -6.986  0.626    3.052    4.10   1.77
# 91608  1005.611 -6.502  0.340    3.089    4.15   1.82
# 91609  1004.732 -5.748  0.044    3.134    4.29   1.75
#
# [91610 rows x 12 columns]
